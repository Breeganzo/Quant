# %% [markdown]
# # Week 2 Sat: Revision, error log, and data workflow drill
#
# Estimated time: 2 hours
#
# ## Why this matters
# Revision, error log, and data workflow drill is part of real quant work inside data and linear algebra: numpy, pandas, visualization, diversification, and sql basics research, trading, or risk workflows.
#
# ## Session plan
# - Session 1 (25 min): Week 2 recall from memory.
# - Session 2 (35 min): SQL and data-cleaning drill.
# - Session 3 (35 min): Error log and concept map.
# - Session 4 (25 min): Interview practice.
#
# ## Concept notes
# ### Revision through active data tasks
# The best review is to clean, compute, and explain again without copying old work.
#
# Technical note: Retrieval plus application is stronger than passive re-reading for building durable technical fluency.
#
# Finance example: Recomputing a correlation matrix from scratch is better review than staring at yesterday's output.
#
# ## Continuity prompt
# - What from yesterday's topic still needs reinforcement?
# - What should tomorrow build on from today?

# %% [markdown]
# ## Code Lab: Quick review drill

# %%
import pandas as pd

review = pd.DataFrame(
    {
        "ticker": ["A", "A", "B", "B"],
        "price": [100, 101, 50, 52],
    }
)
review["return_guess"] = review.groupby("ticker")["price"].pct_change()
print(review)

# %% [markdown]
# ## Practice recap
# - What is one sign you truly understand a data workflow?
#   Suggested answer: You can rebuild it cleanly from memory and explain why each step exists.

# %% [markdown]
# ## Interview drill
# - Q: What is one common data-handling mistake in quant research?
#   A: Misalignment across dates or assets, which can quietly contaminate results.
