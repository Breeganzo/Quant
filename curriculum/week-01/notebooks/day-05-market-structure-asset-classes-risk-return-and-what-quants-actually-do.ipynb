# %% [markdown]
# # Week 1 Fri: Market structure, asset classes, risk, return, and what quants actually do
#
# Estimated time: 10 hours
#
# ## Why this matters
# You need a mental map of markets before learning pricing, forecasting, and strategy research.
#
# ## Study blocks
# - Block 1 (60 min): Concept briefing and key-assumption mapping.
# - Block 2 (60 min): Formula/workflow derivation and notation rewrite.
# - Block 3 (60 min): Solved real-world case walkthrough.
# - Block 4 (60 min): Data checks and exploratory diagnostics.
# - Block 5 (60 min): Core notebook implementation with comments.
# - Block 6 (60 min): Extension coding task and sensitivity variation.
# - Block 7 (60 min): Risk caveat and robustness scenario testing.
# - Block 8 (60 min): Interview-style quiz answers and defense drill.
# - Block 9 (60 min): Revision sprint and error-log updates.
# - Block 10 (60 min): Desk memo summary and tomorrow transition plan.
#
# ## Concept notes
# ### Market structure
# Markets match buyers and sellers. Prices move because participants update beliefs, manage risk, or need liquidity.
#
# Technical note: Market structure includes venues, order types, liquidity conditions, and how trades are executed.
#
# Finance example: A highly liquid index future behaves very differently from a small illiquid stock.
#
# ### Asset classes and risk drivers
# Different instruments are moved by different forces: earnings for equities, rates for bonds, macro and flows for FX, supply and demand for commodities.
#
# Technical note: Each asset class has distinct payoff structures, liquidity patterns, and risk exposures.
#
# Finance example: An equity drawdown, a bond duration shock, and an FX carry unwind are different risk stories.
#
# ### Buy-side, sell-side, and investment banking
# Buy-side manages money and seeks returns. Sell-side serves clients, prices products, runs trading desks, and manages bank-side exposures. Investment banking is more deal-oriented than model-oriented.
#
# Technical note: Buy-side quants focus more on alpha, portfolio construction, and PnL. Sell-side quants often support pricing, structuring, risk, execution, and desk infrastructure.
#
# Finance example: A hedge fund researcher testing a factor signal and a bank derivatives quant calibrating an options model are both quants, but their incentives and workflows differ.

# %% [markdown]
# ## Code Lab 1: Asset class map

# %%
import pandas as pd

asset_map = pd.DataFrame(
    {
        "asset_class": ["Equities", "Fixed Income", "FX", "Commodities", "Options"],
        "return_driver": [
            "earnings and valuation",
            "rates and credit spreads",
            "macro and carry",
            "supply, demand, macro",
            "underlying move and volatility",
        ],
        "main_risk": [
            "equity drawdown",
            "duration and credit risk",
            "macro shocks",
            "supply shock",
            "nonlinear exposure",
        ],
    }
)
print(asset_map)
# Out:
#     asset_class                   return_driver                 main_risk
# 0      Equities          earnings and valuation           equity drawdown
# 1  Fixed Income        rates and credit spreads  duration and credit risk
# 2            FX                 macro and carry              macro shocks
# 3   Commodities           supply, demand, macro              supply shock
# 4       Options  underlying move and volatility        nonlinear exposure

# %% [markdown]
# ## Code Lab 2: Simple turnover-cost example

# %%
gross_alpha_per_trade = 0.0015
cost_per_trade = 0.0008
trades_per_month = 40

monthly_gross = gross_alpha_per_trade * trades_per_month
monthly_net = (gross_alpha_per_trade - cost_per_trade) * trades_per_month

print("Monthly gross return contribution:", round(monthly_gross, 4))
print("Monthly net return contribution:", round(monthly_net, 4))
# Out:
# Monthly gross return contribution: 0.06
# Monthly net return contribution: 0.028

# %% [markdown]
# ## Practice recap
# - Why is investment banking not the same as quant trading?
#   Suggested answer: Investment banking is centered on deals, capital raising, valuation, and client execution, while quant trading focuses on models, risk, pricing, and systematic decision making.
# - What is one major risk driver for fixed income?
#   Suggested answer: Interest rates and the shape of the yield curve are central drivers, along with credit risk for credit products.
# - Why do transaction costs matter more in short-horizon strategies?
#   Suggested answer: Because frequent trading causes costs to accumulate and can easily overwhelm a small raw edge.

# %% [markdown]
# ## Interview drill
# - Q: What is the clearest difference between buy-side and sell-side quant work?
#   A: Buy-side is more directly tied to alpha and portfolio performance, while sell-side is more tied to pricing, client support, structuring, execution, and desk risk.
# - Q: Why should a quant understand market structure early?
#   A: Because signals only matter if they can actually be implemented in the market without unrealistic assumptions.

# %% [markdown]
# ## 10-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Rewrite formulas/workflows and define each term.
# - Phase 3 (60 min): Complete baseline code labs with comments.
# - Phase 4 (60 min): Build one real-data extension and compare outputs.
# - Phase 5 (60 min): Add stress/sensitivity checks and interpret shifts.
# - Phase 6 (60 min): Run scenario analysis and identify fragile assumptions.
# - Phase 7 (60 min): Complete interview-style Python drill with explanation.
# - Phase 8 (60 min): Do closed-book retrieval and update error log.
# - Phase 9 (60 min): Write one desk memo with recommendation and caveat.
# - Phase 10 (60 min): Define next-session experiment plan and confidence score.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': '\\mathrm{Spread}=Ask-Bid', 'from_memory': '', 'term_explanations': ''}, {'formula': '\\mathrm{TO}_t=\\frac{1}{2}\\sum_i|w_{i,t}-w_{i,t-1}|', 'from_memory': '', 'term_explanations': ''}, {'formula': 'S=\\frac{R_{ann}-R_f}{\\sigma_{ann}}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0                            \mathrm{Spread}=Ask-Bid
# 1  \mathrm{TO}_t=\frac{1}{2}\sum_i|w_{i,t}-w_{i,t...
# 2                 S=\frac{R_{ann}-R_f}{\sigma_{ann}}
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Market structure, asset classes, risk, return, and what quants actually do) with one concrete dataset and one measurable output.
#
#         - Use curriculum/datasets/real_market_prices.csv as reproducible fallback data.
# - Build one table and one chart supporting a decision.
# - Document one limitation and one robustness check.

# %%
TASK = 'Compute log returns and summarize annualized return/risk with one caveat.'
print('Lab task:', TASK)

from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
ret = prices.pct_change().dropna()
ann_ret = ret.mean() * 252
ann_vol = ret.std() * (252 ** 0.5)
print(pd.DataFrame({"ann_return": ann_ret, "ann_vol": ann_vol}).round(4))
# Out:
# Lab task: Compute log returns and summarize annualized return/risk with one caveat.
#         ann_return  ann_vol
# symbol
# GLD         0.1856   0.1770
# QQQ         0.1719   0.2247
# SPY         0.1524   0.1698
# TLT        -0.0683   0.1579

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Market structure, asset classes, risk, return, and what quants actually do):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Compute log returns and summarize annualized return/risk with one caveat.

# %%
TASK = 'Compute log returns and summarize annualized return/risk with one caveat.'
print('Interview drill task:', TASK)

from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
ret = prices.pct_change().dropna()
ann_ret = ret.mean() * 252
ann_vol = ret.std() * (252 ** 0.5)
print(pd.DataFrame({"ann_return": ann_ret, "ann_vol": ann_vol}).round(4))
# Out:
# Interview drill task: Compute log returns and summarize annualized return/risk with one caveat.
#         ann_return  ann_vol
# symbol
# GLD         0.1856   0.1770
# QQQ         0.1719   0.2247
# SPY         0.1524   0.1698
# TLT        -0.0683   0.1579

# %% [markdown]
# ## Extended 10-Hour Coding Challenge
#
# Build one additional variant for today's topic (Market structure, asset classes, risk, return, and what quants actually do):
#
# 1. Change one key assumption or parameter.
# 2. Re-run the pipeline and compare baseline vs variant.
# 3. Comment each major step in code so another analyst can audit your logic.
# 4. State whether the recommendation changed and why.

# %%
import pandas as pd

baseline_vs_variant = pd.DataFrame(
    [
        {"run": "baseline", "key_assumption": "", "headline_metric": None, "decision": ""},
        {"run": "variant", "key_assumption": "", "headline_metric": None, "decision": ""},
    ]
)

# Fill this table after running your variant so the comparison is explicit.
print(baseline_vs_variant)
# Out:
#         run key_assumption headline_metric decision
# 0  baseline                           None
# 1   variant                           None

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Market structure, asset classes, risk, return, and what quants actually do')
print(scenarios)
# Out:
# Topic: Market structure, asset classes, risk, return, and what quants actually do
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Market structure, asset classes, risk, return, and what quants actually do in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
