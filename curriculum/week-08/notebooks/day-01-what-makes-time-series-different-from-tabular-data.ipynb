# %% [markdown]
# # Week 8 Mon: What makes time series different from tabular data?
#
#         Estimated time: 10 hours
#
#         ## Why this matters
#         What makes time series different from tabular data? is part of real quant work inside time series i: stationarity, ar/ma/arima intuition, walk-forward testing, and forecasting research, trading, or risk workflows.
#
#         ## Core explanation
#         Build what makes time series different from tabular data? from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for what makes time series different from tabular data? and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: week kickoff and baseline setup.
#
# Next day: Stationarity, trends, seasonality, and differencing

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
spy = market[market["symbol"] == "SPY"].sort_values("date").set_index("date")["close"]
ret = spy.pct_change().dropna()
diag = pd.DataFrame(
    {
        "ret": ret,
        "lag1": ret.shift(1),
        "roll_mean_20": ret.rolling(20).mean(),
        "roll_vol_20": ret.rolling(20).std(),
    }
).dropna()
print("Lag-1 autocorr:", round(diag["ret"].corr(diag["lag1"]), 4))
print(diag.tail())
# Out:
# Lag-1 autocorr: -0.0259
#                  ret      lag1  roll_mean_20  roll_vol_20
# date
# 2026-04-13  0.009772 -0.000662      0.001977     0.012386
# 2026-04-14  0.012185  0.009772      0.002077     0.012464
# 2026-04-15  0.007891  0.012185      0.002340     0.012532
# 2026-04-16  0.002457  0.007891      0.003161     0.011932
# 2026-04-17  0.012086  0.002457      0.003888     0.012014

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'What makes time series different from tabular data?', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'What makes time series different from tabular data?', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'What makes time series different from tabular data?', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                                                topic              assumption  \
# 0  What makes time series different from tabular ...  Data is representative
# 1  What makes time series different from tabular ...  No leakage in pipeline
# 2  What makes time series different from tabular ...     Costs are realistic
#
#                status
# 0  needs verification
# 1          needs test
# 2   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'what makes time series different from tabular data?')
print(stress)
# Out:
# Topic: what makes time series different from tabular data?
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'What makes time series different from tabular data?',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'What makes time series different from tabular data?', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain what makes time series different from tabular data? in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for what makes time series different from tabular data? from memory.
# - Connect what makes time series different from tabular data? to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from what makes time series different from tabular data? is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain what makes time series different from tabular data? and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 10-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Rewrite formulas/workflows and define each term.
# - Phase 3 (60 min): Complete baseline code labs with comments.
# - Phase 4 (60 min): Build one real-data extension and compare outputs.
# - Phase 5 (60 min): Add stress/sensitivity checks and interpret shifts.
# - Phase 6 (60 min): Run scenario analysis and identify fragile assumptions.
# - Phase 7 (60 min): Complete interview-style Python drill with explanation.
# - Phase 8 (60 min): Do closed-book retrieval and update error log.
# - Phase 9 (60 min): Write one desk memo with recommendation and caveat.
# - Phase 10 (60 min): Define next-session experiment plan and confidence score.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'x_t=c+\\phi x_{t-1}+\\epsilon_t', 'from_memory': '', 'term_explanations': ''}, {'formula': '\\sigma_t^2=\\lambda\\sigma_{t-1}^2+(1-\\lambda)r_{t-1}^2', 'from_memory': '', 'term_explanations': ''}, {'formula': '\\mathrm{RMSE}=\\sqrt{\\frac{1}{n}\\sum_{i=1}^{n}(\\hat y_i-y_i)^2}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0                      x_t=c+\phi x_{t-1}+\epsilon_t
# 1  \sigma_t^2=\lambda\sigma_{t-1}^2+(1-\lambda)r_...
# 2  \mathrm{RMSE}=\sqrt{\frac{1}{n}\sum_{i=1}^{n}(...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (What makes time series different from tabular data?) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for what makes time series different from tabular data? instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Compute lag autocorrelation and rolling mean/volatility diagnostics.'
print('Lab task:', TASK)

from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
spy = market[market["symbol"] == "SPY"].sort_values("date").set_index("date")["close"]
ret = spy.pct_change().dropna()
diag = pd.DataFrame(
    {
        "ret": ret,
        "lag1": ret.shift(1),
        "roll_mean_20": ret.rolling(20).mean(),
        "roll_vol_20": ret.rolling(20).std(),
    }
).dropna()
print("Lag-1 autocorr:", round(diag["ret"].corr(diag["lag1"]), 4))
print(diag.tail())
# Out:
# Lab task: Compute lag autocorrelation and rolling mean/volatility diagnostics.
# Lag-1 autocorr: -0.0259
#                  ret      lag1  roll_mean_20  roll_vol_20
# date
# 2026-04-13  0.009772 -0.000662      0.001977     0.012386
# 2026-04-14  0.012185  0.009772      0.002077     0.012464
# 2026-04-15  0.007891  0.012185      0.002340     0.012532
# 2026-04-16  0.002457  0.007891      0.003161     0.011932
# 2026-04-17  0.012086  0.002457      0.003888     0.012014

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (What makes time series different from tabular data?):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Compute lag autocorrelation and rolling mean/volatility diagnostics.

# %%
TASK = 'Compute lag autocorrelation and rolling mean/volatility diagnostics.'
print('Interview drill task:', TASK)

from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
spy = market[market["symbol"] == "SPY"].sort_values("date").set_index("date")["close"]
ret = spy.pct_change().dropna()
diag = pd.DataFrame(
    {
        "ret": ret,
        "lag1": ret.shift(1),
        "roll_mean_20": ret.rolling(20).mean(),
        "roll_vol_20": ret.rolling(20).std(),
    }
).dropna()
print("Lag-1 autocorr:", round(diag["ret"].corr(diag["lag1"]), 4))
print(diag.tail())
# Out:
# Interview drill task: Compute lag autocorrelation and rolling mean/volatility diagnostics.
# Lag-1 autocorr: -0.0259
#                  ret      lag1  roll_mean_20  roll_vol_20
# date
# 2026-04-13  0.009772 -0.000662      0.001977     0.012386
# 2026-04-14  0.012185  0.009772      0.002077     0.012464
# 2026-04-15  0.007891  0.012185      0.002340     0.012532
# 2026-04-16  0.002457  0.007891      0.003161     0.011932
# 2026-04-17  0.012086  0.002457      0.003888     0.012014

# %% [markdown]
# ## Extended 10-Hour Coding Challenge
#
# Build one additional variant for today's topic (What makes time series different from tabular data?):
#
# 1. Change one key assumption or parameter.
# 2. Re-run the pipeline and compare baseline vs variant.
# 3. Comment each major step in code so another analyst can audit your logic.
# 4. State whether the recommendation changed and why.

# %%
import pandas as pd

baseline_vs_variant = pd.DataFrame(
    [
        {"run": "baseline", "key_assumption": "", "headline_metric": None, "decision": ""},
        {"run": "variant", "key_assumption": "", "headline_metric": None, "decision": ""},
    ]
)

# Fill this table after running your variant so the comparison is explicit.
print(baseline_vs_variant)
# Out:
#         run key_assumption headline_metric decision
# 0  baseline                           None
# 1   variant                           None

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'What makes time series different from tabular data?')
print(scenarios)
# Out:
# Topic: What makes time series different from tabular data?
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of What makes time series different from tabular data? in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
