# %% [markdown]
# # Week 8 Thu: Autocorrelation, partial autocorrelation, and lag structure
#
#         Estimated time: 6 hours
#
#         ## Why this matters
#         Autocorrelation, partial autocorrelation, and lag structure is part of real quant work inside time series i: stationarity, ar/ma/arima intuition, walk-forward testing, and forecasting research, trading, or risk workflows.
#
#         ## Core explanation
#         Build autocorrelation, partial autocorrelation, and lag structure from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for autocorrelation, partial autocorrelation, and lag structure and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: AR, MA, and ARIMA intuition
#
# Next day: Walk-forward validation and forecast error metrics

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
from pathlib import Path
import numpy as np
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
spy = market[market["symbol"] == "SPY"].sort_values("date").set_index("date")["close"]
r = spy.pct_change().dropna()
lag1 = r.shift(1).dropna()
y = r.loc[lag1.index]
split = max(30, int(len(y) * 0.8))
pred = lag1.iloc[split:]
truth = y.iloc[split:]
rmse = float(np.sqrt(((pred - truth) ** 2).mean()))
print({"rmse": round(rmse, 6), "test_points": len(truth)})
# Out:
# {'rmse': 0.017799, 'test_points': 266}

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Autocorrelation, partial autocorrelation, and lag structure', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Autocorrelation, partial autocorrelation, and lag structure', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Autocorrelation, partial autocorrelation, and lag structure', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                                                topic              assumption  \
# 0  Autocorrelation, partial autocorrelation, and ...  Data is representative
# 1  Autocorrelation, partial autocorrelation, and ...  No leakage in pipeline
# 2  Autocorrelation, partial autocorrelation, and ...     Costs are realistic
#
#                status
# 0  needs verification
# 1          needs test
# 2   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'autocorrelation, partial autocorrelation, and lag structure')
print(stress)
# Out:
# Topic: autocorrelation, partial autocorrelation, and lag structure
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Autocorrelation, partial autocorrelation, and lag structure',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Autocorrelation, partial autocorrelation, and lag structure', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain autocorrelation, partial autocorrelation, and lag structure in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for autocorrelation, partial autocorrelation, and lag structure from memory.
# - Connect autocorrelation, partial autocorrelation, and lag structure to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from autocorrelation, partial autocorrelation, and lag structure is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain autocorrelation, partial autocorrelation, and lag structure and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 6-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Complete and extend all code labs with at least one variation.
# - Phase 3 (60 min): Do formula retrieval, scenario analysis, and error-log updates.
# - Phase 4 (60 min): Practice interview responses aloud.
# - Phase 5 (60 min): Implement one robustness check.
# - Phase 6 (60 min): Write a concise memo with limitations and next steps.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': '\\mathrm{Cov}(X,Y)=\\frac{1}{n-1}\\sum_i(x_i-\\bar x)(y_i-\\bar y)', 'from_memory': '', 'term_explanations': ''}, {'formula': '\\rho_{XY}=\\frac{\\mathrm{Cov}(X,Y)}{\\sigma_X\\sigma_Y}', 'from_memory': '', 'term_explanations': ''}, {'formula': '\\sigma_p^2=w_1^2\\sigma_1^2+w_2^2\\sigma_2^2+2w_1w_2\\rho_{12}\\sigma_1\\sigma_2', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0  \mathrm{Cov}(X,Y)=\frac{1}{n-1}\sum_i(x_i-\bar...
# 1  \rho_{XY}=\frac{\mathrm{Cov}(X,Y)}{\sigma_X\si...
# 2  \sigma_p^2=w_1^2\sigma_1^2+w_2^2\sigma_2^2+2w_...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Autocorrelation, partial autocorrelation, and lag structure) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for autocorrelation, partial autocorrelation, and lag structure instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Build a lag-based forecast baseline and compute RMSE on the last 30 observations.'
print('Lab task:', TASK)

from pathlib import Path
import numpy as np
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
spy = market[market["symbol"] == "SPY"].sort_values("date").set_index("date")["close"]
r = spy.pct_change().dropna()
lag1 = r.shift(1).dropna()
y = r.loc[lag1.index]
split = max(30, int(len(y) * 0.8))
pred = lag1.iloc[split:]
truth = y.iloc[split:]
rmse = float(np.sqrt(((pred - truth) ** 2).mean()))
print({"rmse": round(rmse, 6), "test_points": len(truth)})
# Out:
# Lab task: Build a lag-based forecast baseline and compute RMSE on the last 30 observations.
# {'rmse': 0.017799, 'test_points': 266}

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Autocorrelation, partial autocorrelation, and lag structure):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Build a lag-based forecast baseline and compute RMSE on the last 30 observations.

# %%
TASK = 'Build a lag-based forecast baseline and compute RMSE on the last 30 observations.'
print('Interview drill task:', TASK)

from pathlib import Path
import numpy as np
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
spy = market[market["symbol"] == "SPY"].sort_values("date").set_index("date")["close"]
r = spy.pct_change().dropna()
lag1 = r.shift(1).dropna()
y = r.loc[lag1.index]
split = max(30, int(len(y) * 0.8))
pred = lag1.iloc[split:]
truth = y.iloc[split:]
rmse = float(np.sqrt(((pred - truth) ** 2).mean()))
print({"rmse": round(rmse, 6), "test_points": len(truth)})
# Out:
# Interview drill task: Build a lag-based forecast baseline and compute RMSE on the last 30 observations.
# {'rmse': 0.017799, 'test_points': 266}

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Autocorrelation, partial autocorrelation, and lag structure')
print(scenarios)
# Out:
# Topic: Autocorrelation, partial autocorrelation, and lag structure
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Autocorrelation, partial autocorrelation, and lag structure in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
