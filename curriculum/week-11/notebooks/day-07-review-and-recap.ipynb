# %% [markdown]
# # Week 11 Sun: Review and recap
#
#         Estimated time: 10 hours
#
#         ## Why this matters
#         Review and recap is part of real quant work inside finance core iii: fixed income, yield curves, duration, convexity, and credit basics research, trading, or risk workflows.
#
#         ## Core explanation
#         Build review and recap from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for review and recap and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Mini lab: simple bond price sensitivity
#
# Next day: weekly consolidation and project integration.

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
import numpy as np

face = 100
coupon = 0.04
y = 0.035
n = 5
cashflows = np.array([face * coupon] * (n - 1) + [face * (1 + coupon)])
times = np.arange(1, n + 1)
discount = (1 + y) ** times
price = (cashflows / discount).sum()
macaulay = ((times * cashflows / discount).sum()) / price
mod_duration = macaulay / (1 + y)
print("Price:", round(float(price), 4))
print("Modified duration:", round(float(mod_duration), 4))
# Out:
# Price: 102.2575
# Modified duration: 4.4779

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Review and recap', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Review and recap', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Review and recap', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#               topic              assumption              status
# 0  Review and recap  Data is representative  needs verification
# 1  Review and recap  No leakage in pipeline          needs test
# 2  Review and recap     Costs are realistic   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'review and recap')
print(stress)
# Out:
# Topic: review and recap
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Review and recap',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Review and recap', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain review and recap in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for review and recap from memory.
# - Connect review and recap to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from review and recap is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain review and recap and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 10-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Rewrite formulas/workflows and define each term.
# - Phase 3 (60 min): Complete baseline code labs with comments.
# - Phase 4 (60 min): Build one real-data extension and compare outputs.
# - Phase 5 (60 min): Add stress/sensitivity checks and interpret shifts.
# - Phase 6 (60 min): Run scenario analysis and identify fragile assumptions.
# - Phase 7 (60 min): Complete interview-style Python drill with explanation.
# - Phase 8 (60 min): Do closed-book retrieval and update error log.
# - Phase 9 (60 min): Write one desk memo with recommendation and caveat.
# - Phase 10 (60 min): Define next-session experiment plan and confidence score.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'P=\\sum_{t=1}^{T}\\frac{CF_t}{(1+y)^t}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'D_{mod}=\\frac{D_{mac}}{1+y}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'C=\\frac{1}{P}\\sum_{t=1}^{T}\\frac{CF_t\\,t(t+1)}{(1+y)^{t+2}}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0               P=\sum_{t=1}^{T}\frac{CF_t}{(1+y)^t}
# 1                        D_{mod}=\frac{D_{mac}}{1+y}
# 2  C=\frac{1}{P}\sum_{t=1}^{T}\frac{CF_t\,t(t+1)}...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Review and recap) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for review and recap instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Price a simple fixed-coupon bond and compute duration approximation.'
print('Lab task:', TASK)

import numpy as np

face = 100
coupon = 0.04
y = 0.035
n = 5
cashflows = np.array([face * coupon] * (n - 1) + [face * (1 + coupon)])
times = np.arange(1, n + 1)
discount = (1 + y) ** times
price = (cashflows / discount).sum()
macaulay = ((times * cashflows / discount).sum()) / price
mod_duration = macaulay / (1 + y)
print("Price:", round(float(price), 4))
print("Modified duration:", round(float(mod_duration), 4))
# Out:
# Lab task: Price a simple fixed-coupon bond and compute duration approximation.
# Price: 102.2575
# Modified duration: 4.4779

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Review and recap):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Price a simple fixed-coupon bond and compute duration approximation.

# %%
TASK = 'Price a simple fixed-coupon bond and compute duration approximation.'
print('Interview drill task:', TASK)

import numpy as np

face = 100
coupon = 0.04
y = 0.035
n = 5
cashflows = np.array([face * coupon] * (n - 1) + [face * (1 + coupon)])
times = np.arange(1, n + 1)
discount = (1 + y) ** times
price = (cashflows / discount).sum()
macaulay = ((times * cashflows / discount).sum()) / price
mod_duration = macaulay / (1 + y)
print("Price:", round(float(price), 4))
print("Modified duration:", round(float(mod_duration), 4))
# Out:
# Interview drill task: Price a simple fixed-coupon bond and compute duration approximation.
# Price: 102.2575
# Modified duration: 4.4779

# %% [markdown]
# ## Extended 10-Hour Coding Challenge
#
# Build one additional variant for today's topic (Review and recap):
#
# 1. Change one key assumption or parameter.
# 2. Re-run the pipeline and compare baseline vs variant.
# 3. Comment each major step in code so another analyst can audit your logic.
# 4. State whether the recommendation changed and why.

# %%
import pandas as pd

baseline_vs_variant = pd.DataFrame(
    [
        {"run": "baseline", "key_assumption": "", "headline_metric": None, "decision": ""},
        {"run": "variant", "key_assumption": "", "headline_metric": None, "decision": ""},
    ]
)

# Fill this table after running your variant so the comparison is explicit.
print(baseline_vs_variant)
# Out:
#         run key_assumption headline_metric decision
# 0  baseline                           None
# 1   variant                           None

# %% [markdown]
# ## Sunday Mini-Project Build

# %%
from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
panel = market.pivot(index="date", columns="symbol", values="close").dropna()
returns = panel.pct_change().dropna()

weights = pd.Series({"SPY": 0.4, "QQQ": 0.3, "TLT": 0.2, "GLD": 0.1})
portfolio = returns.mul(weights, axis=1).sum(axis=1)

report = {
    "annualized_return": float(portfolio.mean() * 252),
    "annualized_vol": float(portfolio.std() * (252 ** 0.5)),
    "best_day": float(portfolio.max()),
    "worst_day": float(portfolio.min()),
}
print({k: round(v, 6) for k, v in report.items()})
# Out:
# {'annualized_return': 0.117434, 'annualized_vol': 0.143589, 'best_day': 0.082893, 'worst_day': -0.042212}

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Review and recap')
print(scenarios)
# Out:
# Topic: Review and recap
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Review and recap in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
