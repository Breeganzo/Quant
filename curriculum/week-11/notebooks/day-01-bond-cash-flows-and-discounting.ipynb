# %% [markdown]
# # Week 11 Mon: Bond cash flows and discounting
#
#         Estimated time: 6 hours
#
#         ## Why this matters
#         Bond cash flows and discounting is part of real quant work inside finance core iii: fixed income, yield curves, duration, convexity, and credit basics research, trading, or risk workflows.
#
#         ## Core explanation
#         Build bond cash flows and discounting from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for bond cash flows and discounting and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: week kickoff and baseline setup.
#
# Next day: Yield, yield curve, and term structure intuition

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
import numpy as np

face = 100
coupon = 0.05
y = 0.04
n = 5
cf = np.array([face * coupon] * (n - 1) + [face * (1 + coupon)])
t = np.arange(1, n + 1)
disc = (1 + y) ** t
price = float((cf / disc).sum())
d_mac = float((t * cf / disc).sum() / price)
d_mod = d_mac / (1 + y)
print({"price": round(price, 4), "mod_duration": round(d_mod, 4)})
# Out:
# {'price': 104.4518, 'mod_duration': 4.3818}

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Bond cash flows and discounting', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Bond cash flows and discounting', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Bond cash flows and discounting', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                              topic              assumption              status
# 0  Bond cash flows and discounting  Data is representative  needs verification
# 1  Bond cash flows and discounting  No leakage in pipeline          needs test
# 2  Bond cash flows and discounting     Costs are realistic   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'bond cash flows and discounting')
print(stress)
# Out:
# Topic: bond cash flows and discounting
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Bond cash flows and discounting',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Bond cash flows and discounting', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain bond cash flows and discounting in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for bond cash flows and discounting from memory.
# - Connect bond cash flows and discounting to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from bond cash flows and discounting is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain bond cash flows and discounting and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 6-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Complete and extend all code labs with at least one variation.
# - Phase 3 (60 min): Do formula retrieval, scenario analysis, and error-log updates.
# - Phase 4 (60 min): Practice interview responses aloud.
# - Phase 5 (60 min): Implement one robustness check.
# - Phase 6 (60 min): Write a concise memo with limitations and next steps.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'P=\\sum_{t=1}^{T}\\frac{CF_t}{(1+y)^t}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'D_{mod}=\\frac{D_{mac}}{1+y}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'C=\\frac{1}{P}\\sum_{t=1}^{T}\\frac{CF_t\\,t(t+1)}{(1+y)^{t+2}}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0               P=\sum_{t=1}^{T}\frac{CF_t}{(1+y)^t}
# 1                        D_{mod}=\frac{D_{mac}}{1+y}
# 2  C=\frac{1}{P}\sum_{t=1}^{T}\frac{CF_t\,t(t+1)}...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Bond cash flows and discounting) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for bond cash flows and discounting instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Price a simple bond and compute modified duration under a yield assumption.'
print('Lab task:', TASK)

import numpy as np

face = 100
coupon = 0.05
y = 0.04
n = 5
cf = np.array([face * coupon] * (n - 1) + [face * (1 + coupon)])
t = np.arange(1, n + 1)
disc = (1 + y) ** t
price = float((cf / disc).sum())
d_mac = float((t * cf / disc).sum() / price)
d_mod = d_mac / (1 + y)
print({"price": round(price, 4), "mod_duration": round(d_mod, 4)})
# Out:
# Lab task: Price a simple bond and compute modified duration under a yield assumption.
# {'price': 104.4518, 'mod_duration': 4.3818}

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Bond cash flows and discounting):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Price a simple bond and compute modified duration under a yield assumption.

# %%
TASK = 'Price a simple bond and compute modified duration under a yield assumption.'
print('Interview drill task:', TASK)

import numpy as np

face = 100
coupon = 0.05
y = 0.04
n = 5
cf = np.array([face * coupon] * (n - 1) + [face * (1 + coupon)])
t = np.arange(1, n + 1)
disc = (1 + y) ** t
price = float((cf / disc).sum())
d_mac = float((t * cf / disc).sum() / price)
d_mod = d_mac / (1 + y)
print({"price": round(price, 4), "mod_duration": round(d_mod, 4)})
# Out:
# Interview drill task: Price a simple bond and compute modified duration under a yield assumption.
# {'price': 104.4518, 'mod_duration': 4.3818}

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Bond cash flows and discounting')
print(scenarios)
# Out:
# Topic: Bond cash flows and discounting
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Bond cash flows and discounting in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
