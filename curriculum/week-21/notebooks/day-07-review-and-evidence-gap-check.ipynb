# %% [markdown]
# # Week 21 Sun: Review and evidence gap check
#
#         Estimated time: 6 hours
#
#         ## Why this matters
#         Review and evidence gap check is part of real quant work inside admissions track i: target programs, scholarships, sop structure, and recommendation strategy research, trading, or risk workflows.
#
#         ## Core explanation
#         Build review and evidence gap check from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for review and evidence gap check and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Mini lab: draft your application story
#
# Next day: weekly consolidation and project integration.

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
import pandas as pd

options = pd.DataFrame(
    {
        "program": ["A", "B", "C"],
        "curriculum_fit": [0.9, 0.8, 0.7],
        "career_fit": [0.8, 0.9, 0.7],
        "cost_score": [0.6, 0.4, 0.9],
    }
)
w = {"curriculum_fit": 0.45, "career_fit": 0.35, "cost_score": 0.20}
options["fit_score"] = (
    options["curriculum_fit"] * w["curriculum_fit"]
    + options["career_fit"] * w["career_fit"]
    + options["cost_score"] * w["cost_score"]
)
print(options.sort_values("fit_score", ascending=False))
# Out:
#   program  curriculum_fit  career_fit  cost_score  fit_score
# 0       A             0.9         0.8         0.6      0.805
# 1       B             0.8         0.9         0.4      0.755
# 2       C             0.7         0.7         0.9      0.740

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Review and evidence gap check', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Review and evidence gap check', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Review and evidence gap check', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                            topic              assumption              status
# 0  Review and evidence gap check  Data is representative  needs verification
# 1  Review and evidence gap check  No leakage in pipeline          needs test
# 2  Review and evidence gap check     Costs are realistic   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'review and evidence gap check')
print(stress)
# Out:
# Topic: review and evidence gap check
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Review and evidence gap check',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Review and evidence gap check', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain review and evidence gap check in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for review and evidence gap check from memory.
# - Connect review and evidence gap check to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from review and evidence gap check is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain review and evidence gap check and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 6-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Complete and extend all code labs with at least one variation.
# - Phase 3 (60 min): Do formula retrieval, scenario analysis, and error-log updates.
# - Phase 4 (60 min): Practice interview responses aloud.
# - Phase 5 (60 min): Implement one robustness check.
# - Phase 6 (60 min): Write a concise memo with limitations and next steps.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'Fit=w_1\\cdot curriculum+w_2\\cdot career+w_3\\cdot cost', 'from_memory': '', 'term_explanations': ''}, {'formula': 'SR=\\frac{grant}{tuition+living}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'NEC=\\frac{\\#supported claims}{\\#total claims}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0  Fit=w_1\cdot curriculum+w_2\cdot career+w_3\cd...
# 1                    SR=\frac{grant}{tuition+living}
# 2      NEC=\frac{\#supported claims}{\#total claims}
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Review and evidence gap check) with one concrete dataset and one measurable output.
#
#         - Build an application matrix with program, cost, scholarship, curriculum fit, and career fit.
# - Score options transparently using weighted criteria.
# - Write one evidence-backed reason for your top choice and one downside risk.
# - Link the matrix directly to today's topic: review and evidence gap check.

# %%
TASK = 'Build a program-fit and cost matrix and rank options by weighted score.'
print('Lab task:', TASK)

import pandas as pd

options = pd.DataFrame(
    {
        "program": ["A", "B", "C"],
        "curriculum_fit": [0.9, 0.8, 0.7],
        "career_fit": [0.8, 0.9, 0.7],
        "cost_score": [0.6, 0.4, 0.9],
    }
)
w = {"curriculum_fit": 0.45, "career_fit": 0.35, "cost_score": 0.20}
options["fit_score"] = (
    options["curriculum_fit"] * w["curriculum_fit"]
    + options["career_fit"] * w["career_fit"]
    + options["cost_score"] * w["cost_score"]
)
print(options.sort_values("fit_score", ascending=False))
# Out:
# Lab task: Build a program-fit and cost matrix and rank options by weighted score.
#   program  curriculum_fit  career_fit  cost_score  fit_score
# 0       A             0.9         0.8         0.6      0.805
# 1       B             0.8         0.9         0.4      0.755
# 2       C             0.7         0.7         0.9      0.740

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Review and evidence gap check):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Build a program-fit and cost matrix and rank options by weighted score.

# %%
TASK = 'Build a program-fit and cost matrix and rank options by weighted score.'
print('Interview drill task:', TASK)

import pandas as pd

options = pd.DataFrame(
    {
        "program": ["A", "B", "C"],
        "curriculum_fit": [0.9, 0.8, 0.7],
        "career_fit": [0.8, 0.9, 0.7],
        "cost_score": [0.6, 0.4, 0.9],
    }
)
w = {"curriculum_fit": 0.45, "career_fit": 0.35, "cost_score": 0.20}
options["fit_score"] = (
    options["curriculum_fit"] * w["curriculum_fit"]
    + options["career_fit"] * w["career_fit"]
    + options["cost_score"] * w["cost_score"]
)
print(options.sort_values("fit_score", ascending=False))
# Out:
# Interview drill task: Build a program-fit and cost matrix and rank options by weighted score.
#   program  curriculum_fit  career_fit  cost_score  fit_score
# 0       A             0.9         0.8         0.6      0.805
# 1       B             0.8         0.9         0.4      0.755
# 2       C             0.7         0.7         0.9      0.740

# %% [markdown]
# ## Sunday Mini-Project Build

# %%
from pathlib import Path
import pandas as pd

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
panel = market.pivot(index="date", columns="symbol", values="close").dropna()
returns = panel.pct_change().dropna()

weights = pd.Series({"SPY": 0.4, "QQQ": 0.3, "TLT": 0.2, "GLD": 0.1})
portfolio = returns.mul(weights, axis=1).sum(axis=1)

report = {
    "annualized_return": float(portfolio.mean() * 252),
    "annualized_vol": float(portfolio.std() * (252 ** 0.5)),
    "best_day": float(portfolio.max()),
    "worst_day": float(portfolio.min()),
}
print({k: round(v, 6) for k, v in report.items()})
# Out:
# {'annualized_return': 0.117434, 'annualized_vol': 0.143589, 'best_day': 0.082893, 'worst_day': -0.042212}

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Review and evidence gap check')
print(scenarios)
# Out:
# Topic: Review and evidence gap check
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Review and evidence gap check in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
