# %% [markdown]
# # Week 12 Sat: Capstone build day
#
#         Estimated time: 6 hours
#
#         ## Why this matters
#         Capstone build day is part of real quant work inside finance core iv: derivatives, options, greeks, hedging, and risk management research, trading, or risk workflows.
#
#         ## Core explanation
#         Build capstone build day from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for capstone build day and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Risk management: VaR, stress, and scenarios
#
# Next day: Capstone review and write-up

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
import numpy as np

k = 100
s_grid = np.linspace(70, 130, 13)
call = np.maximum(s_grid - k, 0)
put = np.maximum(k - s_grid, 0)
s0 = 101
eps = 0.5
call_price = lambda s: max(s - k, 0)
delta = (call_price(s0 + eps) - call_price(s0 - eps)) / (2 * eps)
print("Call payoff:", call)
print("Put payoff:", put)
print("Delta estimate near S=101:", round(float(delta), 4))
# Out:
# Call payoff: [ 0.  0.  0.  0.  0.  0.  0.  5. 10. 15. 20. 25. 30.]
# Put payoff: [30. 25. 20. 15. 10.  5.  0.  0.  0.  0.  0.  0.  0.]
# Delta estimate near S=101: 1.0

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Capstone build day', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Capstone build day', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Capstone build day', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                 topic              assumption              status
# 0  Capstone build day  Data is representative  needs verification
# 1  Capstone build day  No leakage in pipeline          needs test
# 2  Capstone build day     Costs are realistic   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'capstone build day')
print(stress)
# Out:
# Topic: capstone build day
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Capstone build day',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Capstone build day', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain capstone build day in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for capstone build day from memory.
# - Connect capstone build day to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from capstone build day is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain capstone build day and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 6-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Complete and extend all code labs with at least one variation.
# - Phase 3 (60 min): Do formula retrieval, scenario analysis, and error-log updates.
# - Phase 4 (60 min): Practice interview responses aloud.
# - Phase 5 (60 min): Implement one robustness check.
# - Phase 6 (60 min): Write a concise memo with limitations and next steps.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'r_t^{net}=r_t^{gross}-cost_t', 'from_memory': '', 'term_explanations': ''}, {'formula': 'RMSE_{OOS}=\\sqrt{\\frac{1}{n}\\sum_i(\\hat y_i-y_i)^2}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'MDD=\\min_t\\left(\\frac{W_t}{\\max_{s\\le t}W_s}-1\\right)', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0                       r_t^{net}=r_t^{gross}-cost_t
# 1  RMSE_{OOS}=\sqrt{\frac{1}{n}\sum_i(\hat y_i-y_...
# 2  MDD=\min_t\left(\frac{W_t}{\max_{s\le t}W_s}-1...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Capstone build day) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for capstone build day instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Build option payoff vectors and estimate delta numerically at one point.'
print('Lab task:', TASK)

import numpy as np

k = 100
s_grid = np.linspace(70, 130, 13)
call = np.maximum(s_grid - k, 0)
put = np.maximum(k - s_grid, 0)
s0 = 101
eps = 0.5
call_price = lambda s: max(s - k, 0)
delta = (call_price(s0 + eps) - call_price(s0 - eps)) / (2 * eps)
print("Call payoff:", call)
print("Put payoff:", put)
print("Delta estimate near S=101:", round(float(delta), 4))
# Out:
# Lab task: Build option payoff vectors and estimate delta numerically at one point.
# Call payoff: [ 0.  0.  0.  0.  0.  0.  0.  5. 10. 15. 20. 25. 30.]
# Put payoff: [30. 25. 20. 15. 10.  5.  0.  0.  0.  0.  0.  0.  0.]
# Delta estimate near S=101: 1.0

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Capstone build day):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Build option payoff vectors and estimate delta numerically at one point.

# %%
TASK = 'Build option payoff vectors and estimate delta numerically at one point.'
print('Interview drill task:', TASK)

import numpy as np

k = 100
s_grid = np.linspace(70, 130, 13)
call = np.maximum(s_grid - k, 0)
put = np.maximum(k - s_grid, 0)
s0 = 101
eps = 0.5
call_price = lambda s: max(s - k, 0)
delta = (call_price(s0 + eps) - call_price(s0 - eps)) / (2 * eps)
print("Call payoff:", call)
print("Put payoff:", put)
print("Delta estimate near S=101:", round(float(delta), 4))
# Out:
# Interview drill task: Build option payoff vectors and estimate delta numerically at one point.
# Call payoff: [ 0.  0.  0.  0.  0.  0.  0.  5. 10. 15. 20. 25. 30.]
# Put payoff: [30. 25. 20. 15. 10.  5.  0.  0.  0.  0.  0.  0.  0.]
# Delta estimate near S=101: 1.0

# %% [markdown]
# ## Saturday Revision Engine

# %%
import pandas as pd

revision_board = pd.DataFrame(
    [
        {"item": "weak_formula_1", "confidence_before": 0, "confidence_after": 0, "next_review": ""},
        {"item": "weak_concept_1", "confidence_before": 0, "confidence_after": 0, "next_review": ""},
        {"item": "interview_answer_1", "confidence_before": 0, "confidence_after": 0, "next_review": ""},
    ]
)
print(revision_board)
# Out:
#                  item  confidence_before  confidence_after next_review
# 0      weak_formula_1                  0                 0
# 1      weak_concept_1                  0                 0
# 2  interview_answer_1                  0                 0

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Capstone build day')
print(scenarios)
# Out:
# Topic: Capstone build day
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Capstone build day in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
