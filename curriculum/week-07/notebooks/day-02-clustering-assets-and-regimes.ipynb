# %% [markdown]
# # Week 7 Tue: Clustering assets and regimes
#
#         Estimated time: 6 hours
#
#         ## Why this matters
#         Clustering assets and regimes is part of real quant work inside unsupervised learning: clustering, pca, latent structure, and factor intuition research, trading, or risk workflows.
#
#         ## Core explanation
#         Build clustering assets and regimes from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for clustering assets and regimes and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Unsupervised learning overview
#
# Next day: PCA and variance decomposition

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
from pathlib import Path
import pandas as pd
from sklearn.cluster import KMeans

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
ret = prices.pct_change().dropna()
feats = pd.DataFrame({"mean": ret.mean(), "vol": ret.std()})
model = KMeans(n_clusters=2, random_state=7, n_init=10)
feats["cluster"] = model.fit_predict(feats)
print(feats)
# Out:
#             mean       vol  cluster
# symbol
# GLD     0.000737  0.011150        0
# QQQ     0.000682  0.014154        1
# SPY     0.000605  0.010695        0
# TLT    -0.000271  0.009948        0

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Clustering assets and regimes', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Clustering assets and regimes', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Clustering assets and regimes', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                            topic              assumption              status
# 0  Clustering assets and regimes  Data is representative  needs verification
# 1  Clustering assets and regimes  No leakage in pipeline          needs test
# 2  Clustering assets and regimes     Costs are realistic   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'clustering assets and regimes')
print(stress)
# Out:
# Topic: clustering assets and regimes
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Clustering assets and regimes',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Clustering assets and regimes', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain clustering assets and regimes in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for clustering assets and regimes from memory.
# - Connect clustering assets and regimes to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from clustering assets and regimes is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain clustering assets and regimes and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 6-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Complete and extend all code labs with at least one variation.
# - Phase 3 (60 min): Do formula retrieval, scenario analysis, and error-log updates.
# - Phase 4 (60 min): Practice interview responses aloud.
# - Phase 5 (60 min): Implement one robustness check.
# - Phase 6 (60 min): Write a concise memo with limitations and next steps.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': '\\min_{C}\\sum_{k}\\sum_{x_i\\in C_k}||x_i-\\mu_k||^2', 'from_memory': '', 'term_explanations': ''}, {'formula': 's_i=\\frac{b_i-a_i}{\\max(a_i,b_i)}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'd(x,y)=\\sqrt{\\sum_j(x_j-y_j)^2}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                             formula from_memory  \
# 0  \min_{C}\sum_{k}\sum_{x_i\in C_k}||x_i-\mu_k||^2
# 1                 s_i=\frac{b_i-a_i}{\max(a_i,b_i)}
# 2                   d(x,y)=\sqrt{\sum_j(x_j-y_j)^2}
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Clustering assets and regimes) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for clustering assets and regimes instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Cluster symbols by return and volatility features using k-means and report labels.'
print('Lab task:', TASK)

from pathlib import Path
import pandas as pd
from sklearn.cluster import KMeans

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
ret = prices.pct_change().dropna()
feats = pd.DataFrame({"mean": ret.mean(), "vol": ret.std()})
model = KMeans(n_clusters=2, random_state=7, n_init=10)
feats["cluster"] = model.fit_predict(feats)
print(feats)
# Out:
# Lab task: Cluster symbols by return and volatility features using k-means and report labels.
#             mean       vol  cluster
# symbol
# GLD     0.000737  0.011150        0
# QQQ     0.000682  0.014154        1
# SPY     0.000605  0.010695        0
# TLT    -0.000271  0.009948        0

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Clustering assets and regimes):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Cluster symbols by return and volatility features using k-means and report labels.

# %%
TASK = 'Cluster symbols by return and volatility features using k-means and report labels.'
print('Interview drill task:', TASK)

from pathlib import Path
import pandas as pd
from sklearn.cluster import KMeans

market = pd.read_csv(Path("curriculum/datasets/real_market_prices.csv"), parse_dates=["date"])
prices = market.pivot(index="date", columns="symbol", values="close").dropna()
ret = prices.pct_change().dropna()
feats = pd.DataFrame({"mean": ret.mean(), "vol": ret.std()})
model = KMeans(n_clusters=2, random_state=7, n_init=10)
feats["cluster"] = model.fit_predict(feats)
print(feats)
# Out:
# Interview drill task: Cluster symbols by return and volatility features using k-means and report labels.
#             mean       vol  cluster
# symbol
# GLD     0.000737  0.011150        0
# QQQ     0.000682  0.014154        1
# SPY     0.000605  0.010695        0
# TLT    -0.000271  0.009948        0

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Clustering assets and regimes')
print(scenarios)
# Out:
# Topic: Clustering assets and regimes
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Clustering assets and regimes in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
