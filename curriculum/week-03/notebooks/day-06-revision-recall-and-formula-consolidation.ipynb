# %% [markdown]
# # Week 3 Sat: Revision, recall, and formula consolidation
#
# Estimated time: 2 hours
#
# ## Why this matters
# Revision, recall, and formula consolidation is part of real quant work inside math rebuild i: algebra, calculus intuition, probability rules, apis, and monte carlo thinking research, trading, or risk workflows.
#
# ## Session plan
# - Session 1 (25 min): Math recall drill.
# - Session 2 (35 min): Probability and Bayes recap.
# - Session 3 (35 min): Error log and formula rewrite.
# - Session 4 (25 min): Interview practice.
#
# ## Concept notes
# ### Integrated recall
# The goal is to connect the week's ideas rather than memorize them in isolation.
#
# Technical note: Algebra, calculus, and probability support each other in quantitative reasoning, especially when moving between formulas and interpretations.
#
# Finance example: A pricing or risk formula is easier to understand when you can interpret the algebra, the sensitivity, and the uncertainty together.
#
# ## Continuity prompt
# - What from yesterday's topic still needs reinforcement?
# - What should tomorrow build on from today?

# %% [markdown]
# ## Code Lab: Quick formula recap

# %%
import numpy as np

print("log(2):", round(np.log(2), 4))
print("exp(1):", round(np.exp(1), 4))

# %% [markdown]
# ## Practice recap
# - What is the real sign that math is improving?
#   Suggested answer: You can restate the idea in plain English, do a simple calculation, and connect it to a finance use case without freezing.

# %% [markdown]
# ## Interview drill
# - Q: What math topic from this week feels most useful for quant work?
#   A: A good answer is whichever concept you can explain with both intuition and a finance example, such as expected value, derivative as sensitivity, or Bayes-style updating.
