# %% [markdown]
# # Week 9 Thu: Transaction costs and slippage models
#
#         Estimated time: 10 hours
#
#         ## Why this matters
#         Transaction costs and slippage models is part of real quant work inside finance core i: market microstructure, execution, slippage, and transaction costs research, trading, or risk workflows.
#
#         ## Core explanation
#         Build transaction costs and slippage models from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for transaction costs and slippage models and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Order types and execution choices
#
# Next day: Turnover, holding period, and capacity intuition

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
import pandas as pd

weights = pd.DataFrame(
    {
        "SPY": [0.40, 0.35, 0.30],
        "QQQ": [0.30, 0.35, 0.35],
        "TLT": [0.20, 0.20, 0.25],
        "GLD": [0.10, 0.10, 0.10],
    },
    index=["t0", "t1", "t2"],
)
turnover = 0.5 * weights.diff().abs().sum(axis=1).fillna(0.0)
cost_bps = 8
est_cost = turnover * (cost_bps / 10000)
print(pd.DataFrame({"turnover": turnover, "estimated_cost": est_cost}))
# Out:
#     turnover  estimated_cost
# t0      0.00         0.00000
# t1      0.05         0.00004
# t2      0.05         0.00004

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Transaction costs and slippage models', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Transaction costs and slippage models', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Transaction costs and slippage models', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                                    topic              assumption  \
# 0  Transaction costs and slippage models  Data is representative
# 1  Transaction costs and slippage models  No leakage in pipeline
# 2  Transaction costs and slippage models     Costs are realistic
#
#                status
# 0  needs verification
# 1          needs test
# 2   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'transaction costs and slippage models')
print(stress)
# Out:
# Topic: transaction costs and slippage models
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Transaction costs and slippage models',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Transaction costs and slippage models', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain transaction costs and slippage models in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for transaction costs and slippage models from memory.
# - Connect transaction costs and slippage models to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from transaction costs and slippage models is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain transaction costs and slippage models and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 10-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Rewrite formulas/workflows and define each term.
# - Phase 3 (60 min): Complete baseline code labs with comments.
# - Phase 4 (60 min): Build one real-data extension and compare outputs.
# - Phase 5 (60 min): Add stress/sensitivity checks and interpret shifts.
# - Phase 6 (60 min): Run scenario analysis and identify fragile assumptions.
# - Phase 7 (60 min): Complete interview-style Python drill with explanation.
# - Phase 8 (60 min): Do closed-book retrieval and update error log.
# - Phase 9 (60 min): Write one desk memo with recommendation and caveat.
# - Phase 10 (60 min): Define next-session experiment plan and confidence score.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'r_t^{net}=w_{t-1}^Tr_t-c_t', 'from_memory': '', 'term_explanations': ''}, {'formula': 'TO_t=\\frac{1}{2}\\sum_i|w_{i,t}-w_{i,t-1}|', 'from_memory': '', 'term_explanations': ''}, {'formula': 'MDD=\\min_t\\left(\\frac{W_t}{\\max_{s\\le t}W_s}-1\\right)', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0                         r_t^{net}=w_{t-1}^Tr_t-c_t
# 1          TO_t=\frac{1}{2}\sum_i|w_{i,t}-w_{i,t-1}|
# 2  MDD=\min_t\left(\frac{W_t}{\max_{s\le t}W_s}-1...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Transaction costs and slippage models) with one concrete dataset and one measurable output.
#
#         - Use yfinance first for SPY, QQQ, TLT, and GLD when internet is available.
# - If available, validate against a Robinhood-style export CSV for consistency checks.
# - Fall back to curriculum/datasets/real_market_prices.csv for reproducible runs.
# - Design one topic-specific analysis for transaction costs and slippage models instead of reusing generic volatility-only metrics.
# - Document one implementation risk and one robustness check before finalizing conclusions.

# %%
TASK = 'Estimate turnover and a simple cost proxy from a toy rebalance schedule.'
print('Lab task:', TASK)

import pandas as pd

weights = pd.DataFrame(
    {
        "SPY": [0.40, 0.35, 0.30],
        "QQQ": [0.30, 0.35, 0.35],
        "TLT": [0.20, 0.20, 0.25],
        "GLD": [0.10, 0.10, 0.10],
    },
    index=["t0", "t1", "t2"],
)
turnover = 0.5 * weights.diff().abs().sum(axis=1).fillna(0.0)
cost_bps = 8
est_cost = turnover * (cost_bps / 10000)
print(pd.DataFrame({"turnover": turnover, "estimated_cost": est_cost}))
# Out:
# Lab task: Estimate turnover and a simple cost proxy from a toy rebalance schedule.
#     turnover  estimated_cost
# t0      0.00         0.00000
# t1      0.05         0.00004
# t2      0.05         0.00004

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Transaction costs and slippage models):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Estimate turnover and a simple cost proxy from a toy rebalance schedule.

# %%
TASK = 'Estimate turnover and a simple cost proxy from a toy rebalance schedule.'
print('Interview drill task:', TASK)

import pandas as pd

weights = pd.DataFrame(
    {
        "SPY": [0.40, 0.35, 0.30],
        "QQQ": [0.30, 0.35, 0.35],
        "TLT": [0.20, 0.20, 0.25],
        "GLD": [0.10, 0.10, 0.10],
    },
    index=["t0", "t1", "t2"],
)
turnover = 0.5 * weights.diff().abs().sum(axis=1).fillna(0.0)
cost_bps = 8
est_cost = turnover * (cost_bps / 10000)
print(pd.DataFrame({"turnover": turnover, "estimated_cost": est_cost}))
# Out:
# Interview drill task: Estimate turnover and a simple cost proxy from a toy rebalance schedule.
#     turnover  estimated_cost
# t0      0.00         0.00000
# t1      0.05         0.00004
# t2      0.05         0.00004

# %% [markdown]
# ## Extended 10-Hour Coding Challenge
#
# Build one additional variant for today's topic (Transaction costs and slippage models):
#
# 1. Change one key assumption or parameter.
# 2. Re-run the pipeline and compare baseline vs variant.
# 3. Comment each major step in code so another analyst can audit your logic.
# 4. State whether the recommendation changed and why.

# %%
import pandas as pd

baseline_vs_variant = pd.DataFrame(
    [
        {"run": "baseline", "key_assumption": "", "headline_metric": None, "decision": ""},
        {"run": "variant", "key_assumption": "", "headline_metric": None, "decision": ""},
    ]
)

# Fill this table after running your variant so the comparison is explicit.
print(baseline_vs_variant)
# Out:
#         run key_assumption headline_metric decision
# 0  baseline                           None
# 1   variant                           None

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Transaction costs and slippage models')
print(scenarios)
# Out:
# Topic: Transaction costs and slippage models
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Transaction costs and slippage models in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
