# %% [markdown]
# # Week 23 Sat: Mock presentation day
#
#         Estimated time: 10 hours
#
#         ## Why this matters
#         Mock presentation day is part of real quant work inside interview prep ii: portfolio polish, github presentation, networking, and mock case defense research, trading, or risk workflows.
#
#         ## Core explanation
#         Build mock presentation day from intuition to implementation: define the core mechanism, map it to measurable outputs, and state one assumption that can break in live deployment.
#
#         ## Worked example
#         Run one compact, reproducible example for mock presentation day and explain both the signal and the main failure mode a quant team should watch.
#
#         ## Continuity
#         Previous day: Behavioral stories for finance roles
#
# Next day: Review and polish

# %% [markdown]
# ## Code Lab 1: Topic-specific implementation

# %%
import pandas as pd

story = pd.DataFrame(
    [
        {"claim": "Signal improves net return", "evidence": "backtest table", "supported": 1},
        {"claim": "Robust in all regimes", "evidence": "none", "supported": 0},
        {"claim": "Risk is controlled", "evidence": "drawdown chart", "supported": 1},
    ]
)
coverage = float(story["supported"].mean())
print(story)
print("evidence_coverage:", round(coverage, 3))
# Out:
#                         claim        evidence  supported
# 0  Signal improves net return  backtest table          1
# 1       Robust in all regimes            none          0
# 2          Risk is controlled  drawdown chart          1
# evidence_coverage: 0.667

# %% [markdown]
# ## Code Lab 2: Assumption register

# %%
import pandas as pd

assumptions = pd.DataFrame(
    [
        {"topic": 'Mock presentation day', "assumption": "Data is representative", "status": "needs verification"},
        {"topic": 'Mock presentation day', "assumption": "No leakage in pipeline", "status": "needs test"},
        {"topic": 'Mock presentation day', "assumption": "Costs are realistic", "status": "needs calibration"},
    ]
)
print(assumptions)
# Out:
#                    topic              assumption              status
# 0  Mock presentation day  Data is representative  needs verification
# 1  Mock presentation day  No leakage in pipeline          needs test
# 2  Mock presentation day     Costs are realistic   needs calibration

# %% [markdown]
# ## Code Lab 3: Sensitivity or stress note

# %%
import pandas as pd

stress = pd.DataFrame(
    [
        {"scenario": "base", "impact": "baseline output"},
        {"scenario": "adverse", "impact": "degradation expected"},
        {"scenario": "extreme", "impact": "failure boundary"},
    ]
)
print("Topic:", 'mock presentation day')
print(stress)
# Out:
# Topic: mock presentation day
#   scenario                impact
# 0     base       baseline output
# 1  adverse  degradation expected
# 2  extreme      failure boundary

# %% [markdown]
# ## Code Lab 4: Study-note structure for revision

# %%
study_note = {
    "topic": 'Mock presentation day',
    "main_formula_or_workflow": "",
    "what_worked": "",
    "failure_mode": "",
    "next_review_date": "",
}
print(study_note)
# Out:
# {'topic': 'Mock presentation day', 'main_formula_or_workflow': '', 'what_worked': '', 'failure_mode': '', 'next_review_date': ''}

# %% [markdown]
# ## Practice recap
# - Explain mock presentation day in one paragraph without jargon.
# - Write down one topic-specific formula or workflow for mock presentation day from memory.
# - Connect mock presentation day to one realistic trading, portfolio, risk, or research decision.
# - Reflection prompt: What from mock presentation day is now evidence-backed in your notes, and what still needs a focused retry?
# - Deliverable: write a 100-word note connecting today's topic to a real trading or risk decision.

# %% [markdown]
# ## Interview drill
# - Q: Explain mock presentation day and one real quant use case.
# - A: Start with intuition, provide one technical detail, and connect it to a trading, portfolio, or risk decision.
# - Q: What would go wrong if this concept is applied carelessly?
# - A: Discuss one realistic failure mode and how you would detect it.

# %% [markdown]
# ## 10-Hour Completion Roadmap
#
# Use this minimum structure to turn today's notebook into a serious study session:
#
# - Phase 1 (60 min): Read concept notes and rewrite the core idea from memory.
# - Phase 2 (60 min): Rewrite formulas/workflows and define each term.
# - Phase 3 (60 min): Complete baseline code labs with comments.
# - Phase 4 (60 min): Build one real-data extension and compare outputs.
# - Phase 5 (60 min): Add stress/sensitivity checks and interpret shifts.
# - Phase 6 (60 min): Run scenario analysis and identify fragile assumptions.
# - Phase 7 (60 min): Complete interview-style Python drill with explanation.
# - Phase 8 (60 min): Do closed-book retrieval and update error log.
# - Phase 9 (60 min): Write one desk memo with recommendation and caveat.
# - Phase 10 (60 min): Define next-session experiment plan and confidence score.

# %% [markdown]
# ## Formula Rewrite Drill

# %%
import pandas as pd

formula_drill = pd.DataFrame(
    [{'formula': 'EC=\\frac{\\#claims\\ with\\ evidence}{\\#claims}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'CR=\\frac{\\#actionable\\ points}{\\#total\\ points}', 'from_memory': '', 'term_explanations': ''}, {'formula': 'LDR=\\frac{\\#explicit\\ limitations}{\\#major\\ findings}', 'from_memory': '', 'term_explanations': ''}]
)
print(formula_drill)
# Out:
#                                              formula from_memory  \
# 0       EC=\frac{\#claims\ with\ evidence}{\#claims}
# 1    CR=\frac{\#actionable\ points}{\#total\ points}
# 2  LDR=\frac{\#explicit\ limitations}{\#major\ fi...
#
#   term_explanations
# 0
# 1
# 2

# %% [markdown]
# ## Real Market Data Lab (Topic-Aligned)
#
#         Use today's topic (Mock presentation day) with one concrete dataset and one measurable output.
#
#         - Create a claim-evidence table for your presentation/case write-up.
# - Add one explicit limitations section with at least three concrete caveats.
# - Convert analysis outputs into decision-ready bullet points for a stakeholder.

# %%
TASK = 'Create a claim-evidence table for a portfolio story and compute evidence coverage.'
print('Lab task:', TASK)

import pandas as pd

story = pd.DataFrame(
    [
        {"claim": "Signal improves net return", "evidence": "backtest table", "supported": 1},
        {"claim": "Robust in all regimes", "evidence": "none", "supported": 0},
        {"claim": "Risk is controlled", "evidence": "drawdown chart", "supported": 1},
    ]
)
coverage = float(story["supported"].mean())
print(story)
print("evidence_coverage:", round(coverage, 3))
# Out:
# Lab task: Create a claim-evidence table for a portfolio story and compute evidence coverage.
#                         claim        evidence  supported
# 0  Signal improves net return  backtest table          1
# 1       Robust in all regimes            none          0
# 2          Risk is controlled  drawdown chart          1
# evidence_coverage: 0.667

# %% [markdown]
# ## Real-World Takeaway Prompt
#
# Write 5-8 lines for today's topic (Mock presentation day):
#
# 1. Which symbol looked most volatile and why that matters.
# 2. Which pair looked most diversifying.
# 3. One realistic portfolio/risk decision you could make from this table.

# %% [markdown]
# ## Interview Question + Python Solution Drill
#
# Use this format for interview preparation:
#
# 1. State the question clearly.
# 2. Explain your approach in plain language.
# 3. Write Python code on relevant data.
# 4. Interpret one risk caveat in words.
#
# **Drill prompt**
# - Create a claim-evidence table for a portfolio story and compute evidence coverage.

# %%
TASK = 'Create a claim-evidence table for a portfolio story and compute evidence coverage.'
print('Interview drill task:', TASK)

import pandas as pd

story = pd.DataFrame(
    [
        {"claim": "Signal improves net return", "evidence": "backtest table", "supported": 1},
        {"claim": "Robust in all regimes", "evidence": "none", "supported": 0},
        {"claim": "Risk is controlled", "evidence": "drawdown chart", "supported": 1},
    ]
)
coverage = float(story["supported"].mean())
print(story)
print("evidence_coverage:", round(coverage, 3))
# Out:
# Interview drill task: Create a claim-evidence table for a portfolio story and compute evidence coverage.
#                         claim        evidence  supported
# 0  Signal improves net return  backtest table          1
# 1       Robust in all regimes            none          0
# 2          Risk is controlled  drawdown chart          1
# evidence_coverage: 0.667

# %% [markdown]
# ## Extended 10-Hour Coding Challenge
#
# Build one additional variant for today's topic (Mock presentation day):
#
# 1. Change one key assumption or parameter.
# 2. Re-run the pipeline and compare baseline vs variant.
# 3. Comment each major step in code so another analyst can audit your logic.
# 4. State whether the recommendation changed and why.

# %%
import pandas as pd

baseline_vs_variant = pd.DataFrame(
    [
        {"run": "baseline", "key_assumption": "", "headline_metric": None, "decision": ""},
        {"run": "variant", "key_assumption": "", "headline_metric": None, "decision": ""},
    ]
)

# Fill this table after running your variant so the comparison is explicit.
print(baseline_vs_variant)
# Out:
#         run key_assumption headline_metric decision
# 0  baseline                           None
# 1   variant                           None

# %% [markdown]
# ## Saturday Revision Engine

# %%
import pandas as pd

revision_board = pd.DataFrame(
    [
        {"item": "weak_formula_1", "confidence_before": 0, "confidence_after": 0, "next_review": ""},
        {"item": "weak_concept_1", "confidence_before": 0, "confidence_after": 0, "next_review": ""},
        {"item": "interview_answer_1", "confidence_before": 0, "confidence_after": 0, "next_review": ""},
    ]
)
print(revision_board)
# Out:
#                  item  confidence_before  confidence_after next_review
# 0      weak_formula_1                  0                 0
# 1      weak_concept_1                  0                 0
# 2  interview_answer_1                  0                 0

# %% [markdown]
# ## Scenario Analysis Drill

# %%
import pandas as pd

scenarios = pd.DataFrame(
    [
        {"scenario": "base_case", "assumption": "", "expected_effect": ""},
        {"scenario": "bull_case", "assumption": "", "expected_effect": ""},
        {"scenario": "stress_case", "assumption": "", "expected_effect": ""},
    ]
)
print("Topic:", 'Mock presentation day')
print(scenarios)
# Out:
# Topic: Mock presentation day
#       scenario assumption expected_effect
# 0    base_case
# 1    bull_case
# 2  stress_case

# %% [markdown]
# ## Closed-Book Retrieval and Error Log

# %%
import pandas as pd

retrieval_scorecard = pd.DataFrame(
    [
        {"prompt": "Explain today's concept in 3 lines", "score_0_to_5": None, "notes": ""},
        {"prompt": "Write one key formula without notes", "score_0_to_5": None, "notes": ""},
        {"prompt": "Give one realistic failure mode", "score_0_to_5": None, "notes": ""},
        {"prompt": "Connect to one trading/risk decision", "score_0_to_5": None, "notes": ""},
    ]
)

error_log = pd.DataFrame(
    [
        {
            "concept": "",
            "mistake": "",
            "correction": "",
            "next_review_date": "",
        }
    ]
)
print("Retrieval scorecard template:")
print(retrieval_scorecard)
print("\nError log template:")
print(error_log)
# Out:
# Retrieval scorecard template:
#                                  prompt score_0_to_5 notes
# 0    Explain today's concept in 3 lines         None
# 1   Write one key formula without notes         None
# 2       Give one realistic failure mode         None
# 3  Connect to one trading/risk decision         None
#
# Error log template:
#   concept mistake correction next_review_date
# 0

# %% [markdown]
# ## Final 30-Minute Deliverable
#
# Write a short memo (150-250 words) with this structure:
#
# 1. Core idea of Mock presentation day in plain language.
# 2. One technical detail or formula and why it matters.
# 3. One practical quant use case.
# 4. One limitation or failure mode and how you would detect it.
